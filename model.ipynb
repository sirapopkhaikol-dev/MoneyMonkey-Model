# %%
# %pip install numpy matplotlib scikit-learn tensorflow pandas openpyxl
# Out:
# Requirement already satisfied: numpy in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (2.4.4)
# Requirement already satisfied: matplotlib in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (3.10.8)
# Requirement already satisfied: scikit-learn in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (1.8.0)
# Requirement already satisfied: tensorflow in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (2.21.0)
# Requirement already satisfied: pandas in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (3.0.2)
# Collecting openpyxl
#   Obtaining dependency information for openpyxl from https://files.pythonhosted.org/packages/c0/da/977ded879c29cbd04de313843e76868e6e13408a94ed6b987245dc7c8506/openpyxl-3.1.5-py2.py3-none-any.whl.metadata
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sirap\appdata\roaming\python\python312\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sirap\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.33.1)
# Requirement already satisfied: setuptools in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\sirap\appdata\roaming\python\python312\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (1.80.0)
# Requirement already satisfied: keras>=3.12.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: tzdata in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.3)
# Collecting et-xmlfile (from openpyxl)
#   Obtaining dependency information for et-xmlfile from https://files.pythonhosted.org/packages/c1/8b/5fe2cc11fee489817272089c4203e679c63b570a5aaeb18d852ae3cbba6a/et_xmlfile-2.0.0-py3-none-any.whl.metadata
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sirap\appdata\roaming\python\python312\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ------------------- -------------------- 122.9/250.9 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 250.9/250.9 kB 3.1 MB/s eta 0:00:00
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
import pandas as pd
import openpyxl

# %%
sheet_id = "1_NMyB8X2HOFj09tU6rtjmRwEuT6E1fK1El9E-ceA0Pw"
sheet_name = "Sheet1"   # เปลี่ยนเป็นชื่อ Sheet ที่ต้องการ ถ้า sheet ชื่ออื่นให้ใส่ตรงนี้

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# อ่านเข้า pandas
df = pd.read_csv(url)

# เลือกแถวที่ 14 และ 24 และแปลงค่าเป็น float
inflation_change_data = df.iloc[13, 2:47].astype(float).values
current_account_data = df.iloc[23, 2:47].astype(float).values

# แสดงข้อมูลที่เลือก
print("Inflation Data:", inflation_change_data)
print("Current Account Data:", current_account_data)

# รวมข้อมูลทั้งสองปัจจัยเป็น 2D array
combined_data = np.column_stack((inflation_change_data, current_account_data))

# สร้างลำดับข้อมูล
def create_dataset(data, time_step=1):
    X, y = [], []
    for i in range(len(data) - time_step):
        X.append(data[i:(i + time_step)])
        y.append(data[i + time_step, 0])  # เป้าหมายคือ % การเปลี่ยนแปลงของอัตราเงินเฟ้อ
    return np.array(X), np.array(y)

# ใช้ time_step = 1 เพื่อความง่าย
time_step = 1
X, y = create_dataset(combined_data, time_step)

# ปรับขนาดข้อมูลให้อยู่ในช่วง [0, 1]
scaler_X = MinMaxScaler(feature_range=(0, 10))
scaler_y = MinMaxScaler(feature_range=(0, 10))
X_scaled = scaler_X.fit_transform(X.reshape(-1, X.shape[2])).reshape(X.shape)
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1))

# แบ่งข้อมูลเป็นชุดฝึกและชุดทดสอบ
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3, random_state=42)

# ปรับรูปแบบข้อมูลให้เป็น [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

# สร้างโมเดล LSTM ด้วยชั้น LSTM สองชั้น
model = Sequential()

# ชั้น LSTM แรก - ตั้งค่า return_sequences=True เพื่อส่งค่าผลลัพธ์ไปยังชั้นถัดไป
model.add(LSTM(units=200, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))

# ชั้น LSTM ที่สอง
model.add(LSTM(units=100))  # เปลี่ยนจำนวน units ได้ตามต้องการ

# ชั้น Dense สุดท้าย
model.add(Dense(1))

# ปรับ optimizer โดยกำหนดค่า learning rate ที่ต้องการ (เช่น 0.0005)
optimizer = Adam(learning_rate=0.001)

# คอมไพล์โมเดลด้วย optimizer ที่ปรับแล้ว
model.compile(optimizer=optimizer, loss='mean_squared_error')

# ฝึกโมเดล
model.fit(X_train, y_train, epochs=100, batch_size=5, verbose=1)

# คาดการณ์ข้อมูล
y_pred_scaled = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_test_inv = scaler_y.inverse_transform(y_test)

# จำนวนปีที่ต้องการคาดการณ์
n_years = 50 # รับค่าจำนวนปีจากผู้ใช้
future_predictions = []

# เริ่มจากข้อมูลล่าสุด
last_data = combined_data[-time_step:]

# ค่ามาตรฐานของ noise (สามารถปรับได้)
noise_std = 0.5 # กำหนดค่าที่มากขึ้นหรือน้อยลงตามที่ต้องการ
future_predictions = []

for i in range(n_years):
    # ปรับขนาดข้อมูลให้สอดคล้องกับ scaler
    last_data_scaled = scaler_X.transform(last_data)
    last_data_scaled = np.reshape(last_data_scaled, (1, time_step, last_data_scaled.shape[1]))
    
    # คาดการณ์ปีถัดไป
    next_year_scaled = model.predict(last_data_scaled)
    next_year = scaler_y.inverse_transform(next_year_scaled)[0][0]
    
    # เพิ่มความผันผวนแบบสุ่ม
    volatility = np.random.normal(0, noise_std)  # สร้างความผันผวนแบบสุ่ม
    next_year += volatility  # ผสมผลคาดการณ์กับความผันผวน

    # เก็บผลการคาดการณ์
    future_predictions.append(next_year)
    
    # ปรับ last_data เพื่อใช้ในการคาดการณ์ปีถัดไป
    next_current_account = current_account_data[len(inflation_change_data) + i] if len(inflation_change_data) + i < len(current_account_data) else next_year * 10
    next_data = np.append(last_data[1:], [[next_year, next_current_account]], axis=0)
    last_data = next_data

# แสดงผลการคาดการณ์
for i, pred in enumerate(future_predictions):
    print(f'Predicted % Inflation Change for year {len(inflation_change_data) + i + 1}: {pred:.2f}')

# พล็อตกราฟการคาดการณ์ตามจำนวนปีที่กำหนด
plt.figure(figsize=(10, 6))

# พล็อตข้อมูลจริง (% การเปลี่ยนแปลงของอัตราเงินเฟ้อ)
plt.scatter(np.arange(1, len(inflation_change_data) + 1), inflation_change_data, color='blue', label='Actual Inflation Change')

# ตรวจสอบขนาดของ combined_data ก่อน reshape
print(f"Original combined data shape: {combined_data.shape}")

# ตรวจสอบว่าจำนวนข้อมูลเพียงพอสำหรับการสร้างลำดับตาม time step หรือไม่
if len(combined_data) > time_step:
    # แปลงข้อมูลเต็มรูปแบบและปรับขนาดใหม่สำหรับ time step = 5
    X_full_scaled = scaler_X.transform(np.reshape(combined_data[:-1], (-1, combined_data.shape[1])))
    
    # แก้ไข reshape ให้ใช้เฉพาะข้อมูลที่สามารถแบ่งได้ตาม time step
    X_full_scaled = np.reshape(X_full_scaled[:len(X_full_scaled) - len(X_full_scaled) % time_step], (-1, time_step, combined_data.shape[1]))
    print(f"Reshaped X_full_scaled shape: {X_full_scaled.shape}")

    # ทำนายข้อมูลในอดีต (historical data) โดยใช้โมเดล
    predicted_full_scaled = model.predict(X_full_scaled)
    predicted_full = scaler_y.inverse_transform(predicted_full_scaled)

    # พล็อตกราฟสำหรับ historical data และการคาดการณ์
    plt.plot(np.arange(1, len(predicted_full) + 1), predicted_full, color='red', label='LSTM Prediction (Historical Data)')
else:
    print(f"Not enough data for the chosen time_step ({time_step})")

# พล็อตการคาดการณ์ในจำนวนปีที่กำหนด
years = np.arange(len(inflation_change_data) + 1, len(inflation_change_data) + n_years + 1)
plt.plot(years, future_predictions, color='orange', linestyle='--', label=f'LSTM Prediction (Next {n_years} Years)')

# พล็อตจุดการคาดการณ์ในแต่ละปีถัดไป
for i in range(n_years):
    plt.scatter(len(inflation_change_data) + i + 1, future_predictions[i], color='green', marker='x', s=100, label=f'Predicted Change for year {len(inflation_change_data) + i + 1}' if i == 0 else "")

# เพิ่มชื่อและรายละเอียดกราฟ
plt.title(f'% Inflation Rate Change Prediction using LSTM (Next {n_years} Years)')
plt.xlabel('Year')
plt.ylabel('% Inflation Change')
plt.legend()
plt.grid(True)
plt.show()

# วัด Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test_inv, y_pred)
print(f'Mean Absolute Error (MAE): {mae:.2f}')

# วัด Mean Squared Error (MSE)
mse = mean_squared_error(y_test_inv, y_pred)
print(f'Mean Squared Error (MSE): {mse:.2f}')

# วัด Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse:.2f}')

from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# กำหนดเปอร์เซ็นต์ความแตกต่างที่ยอมรับได้ (เช่น 10%)
tolerance = 0.03

# คำนวณจำนวนที่คาดการณ์ "ถูกต้อง"
correct_predictions = np.sum(np.abs(predicted_full - inflation_change_data) / np.abs(inflation_change_data) <= tolerance)

# คำนวณ Accuracy เป็นเปอร์เซ็นต์
accuracy = correct_predictions / len(inflation_change_data) * 100
print(f'Accuracy: {accuracy:.2f}%')

# คำนวณ MAE และ RMSE ระหว่างข้อมูลจริงและการคาดการณ์ historical data
if len(predicted_full) == len(inflation_change_data):
    mae = mean_absolute_error(inflation_change_data, predicted_full)
    rmse = np.sqrt(mean_squared_error(inflation_change_data, predicted_full))
    print(f'Mean Absolute Error (MAE): {mae:.4f}')
    print(f'Root Mean Squared Error (RMSE): {rmse:.4f}')
else:
    print(f"Shape mismatch: predicted_full ({len(predicted_full)}) vs inflation_change_data ({len(inflation_change_data)})")


   



print(future_predictions)


def predict(n_years,initial_amount):

    # ตรวจสอบว่าค่า n_years อยู่ในช่วง 1 ถึง 50  
    if n_years > 50:
        n_years = 50
    elif n_years < 1:
        n_years = 1

    # คำนวณเงินหลังจากการบวกเงินเฟ้อในแต่ละปี
    amount = initial_amount
    result = []  # เพื่อเก็บจำนวนเงินของแต่ละปี

    for i in range(n_years):
        inflat_rate = future_predictions[i] / 100  # เปลี่ยนจาก % เป็นทศนิยม
        amount += amount*inflat_rate # บวกเปอร์เซ็นต์เงินเฟ้อในปีนั้น
        result.append({
            'year': i+1,
            'inflation_rate': future_predictions[i],
            'amount': round(amount,2) # ปัดเศษให้เหลือ 2 ตำแหน่ง
        })
    
    return result
# Out:
# Inflation Data: [ 9.9  19.71 12.77  5.18  3.76  0.88  2.48  1.9   2.4   3.9   5.3   5.93
#   5.7   4.1   3.52  5.    5.71  5.95  5.61  7.89  0.3   1.6   1.6   0.7
#   1.8   2.7   4.5   4.7   2.3   5.5  -0.9   3.3   3.81  3.01  2.18  1.9
#  -0.9   0.18  0.67  1.07  0.7  -0.85  1.23  6.08  1.23]
# Current Account Data: [-7.6 -6.4 -7.4 -2.8 -7.2 -5.  -3.9  0.7 -0.6 -2.4 -3.3 -8.3 -7.5 -5.5
#  -4.9 -5.4 -7.9 -7.9 -2.  12.7 10.2  9.2  7.   6.8  7.3  6.2 -4.   1.
#   5.9  0.3  7.9  3.3  2.6 -1.2 -2.   2.9  6.9 10.5  9.6  5.6  7.   4.2
#  -2.1 -3.5  1.4]
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# c:\Users\Sirap\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 9.5669
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5337
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4827
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0023
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9646
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0535
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5499
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9585
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4892
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2565
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1850
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1539
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1466
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1543
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1402
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1231
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1123
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0774
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0900
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1003
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0678
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0531
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0665
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0587
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0488
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0355
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0545
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0329
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0317
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0251
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0143
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0037
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0102
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0649
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0451
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9866
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0922
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9902
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9780
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0093
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9731
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9583
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9580
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9704
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9714
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9535
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9397
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9615
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9428
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9735
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9495
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9456
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9357
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9404
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9477
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9367
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9408
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9329
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9179
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9217
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9188
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9316
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9344
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9052
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9254
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8996
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9159
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9169
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9235
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9586
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9157
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8918
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8992
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9123
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9149
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9384
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8847
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9192
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8900
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8789
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9051
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8869
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9075
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9084
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8959
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8874
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9403
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8840
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8686
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9445
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9061
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8794
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9041
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8801
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8888
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8776
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8682
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9029
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8861
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8715
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Predicted % Inflation Change for year 46: 1.54
# Predicted % Inflation Change for year 47: 1.27
# Predicted % Inflation Change for year 48: 1.50
# Predicted % Inflation Change for year 49: 1.70
# Predicted % Inflation Change for year 50: 1.75
# Predicted % Inflation Change for year 51: 1.11
# Predicted % Inflation Change for year 52: 1.70
# Predicted % Inflation Change for year 53: 0.95
# Predicted % Inflation Change for year 54: 1.42
# Predicted % Inflation Change for year 55: 2.21
# Predicted % Inflation Change for year 56: 0.78
# Predicted % Inflation Change for year 57: 1.39
# Predicted % Inflation Change for year 58: 1.69
# Predicted % Inflation Change for year 59: 1.15
# Predicted % Inflation Change for year 60: 1.52
# Predicted % Inflation Change for year 61: 0.64
# Predicted % Inflation Change for year 62: 1.70
# Predicted % Inflation Change for year 63: 1.62
# Predicted % Inflation Change for year 64: 0.84
# Predicted % Inflation Change for year 65: 1.53
# Predicted % Inflation Change for year 66: 1.46
# Predicted % Inflation Change for year 67: 1.31
# Predicted % Inflation Change for year 68: 1.51
# Predicted % Inflation Change for year 69: 1.77
# Predicted % Inflation Change for year 70: 1.18
# Predicted % Inflation Change for year 71: 0.51
# Predicted % Inflation Change for year 72: 1.52
# Predicted % Inflation Change for year 73: 1.18
# Predicted % Inflation Change for year 74: 2.40
# Predicted % Inflation Change for year 75: 2.03
# Predicted % Inflation Change for year 76: 0.57
# Predicted % Inflation Change for year 77: 1.67
# Predicted % Inflation Change for year 78: 0.80
# Predicted % Inflation Change for year 79: 1.09
# Predicted % Inflation Change for year 80: 1.38
# Predicted % Inflation Change for year 81: 0.85
# Predicted % Inflation Change for year 82: 1.20
# Predicted % Inflation Change for year 83: 1.50
# Predicted % Inflation Change for year 84: 1.99
# Predicted % Inflation Change for year 85: 2.17
# Predicted % Inflation Change for year 86: 2.08
# Predicted % Inflation Change for year 87: 1.42
# Predicted % Inflation Change for year 88: 1.89
# Predicted % Inflation Change for year 89: 1.72
# Predicted % Inflation Change for year 90: 1.31
# Predicted % Inflation Change for year 91: 1.94
# Predicted % Inflation Change for year 92: 1.01
# Predicted % Inflation Change for year 93: 2.30
# Predicted % Inflation Change for year 94: 0.79
# Predicted % Inflation Change for year 95: 1.91
# Original combined data shape: (45, 2)
# Reshaped X_full_scaled shape: (44, 1, 2)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Mean Absolute Error (MAE): 1.64
# Mean Squared Error (MSE): 3.64
# Root Mean Squared Error (RMSE): 1.91
# Accuracy: 77.78%
# Shape mismatch: predicted_full (44) vs inflation_change_data (45)
# [np.float32(1.5358217), np.float32(1.2713441), np.float32(1.4956), np.float32(1.7012875), np.float32(1.7514179), np.float32(1.1143591), np.float32(1.6961958), np.float32(0.95238745), np.float32(1.4244092), np.float32(2.2116137), np.float32(0.77554655), np.float32(1.3925551), np.float32(1.6913865), np.float32(1.1526375), np.float32(1.5247159), np.float32(0.6384429), np.float32(1.6956271), np.float32(1.6237043), np.float32(0.8385519), np.float32(1.5347104), np.float32(1.4556826), np.float32(1.3127971), np.float32(1.5094477), np.float32(1.7744792), np.float32(1.1819193), np.float32(0.5084252), np.float32(1.5226585), np.float32(1.1765789), np.float32(2.4027238), np.float32(2.0343053), np.float32(0.5720005), np.float32(1.6714666), np.float32(0.8015246), np.float32(1.0948796), np.float32(1.3835871), np.float32(0.8500159), np.float32(1.1950561), np.float32(1.501859), np.float32(1.9880927), np.float32(2.169687), np.float32(2.075569), np.float32(1.4167057), np.float32(1.8861256), np.float32(1.718328), np.float32(1.3119336), np.float32(1.9389334), np.float32(1.0116459), np.float32(2.3001368), np.float32(0.7935357), np.float32(1.9110266)]

# %%
# %pip install flask importnb
# Out:
# Requirement already satisfied: flask in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (3.1.3)
# Requirement already satisfied: importnb in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (2023.11.1)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from flask) (8.4.2)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from flask) (3.0.3)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\sirap\appdata\local\programs\python\python312\lib\site-packages (from flask) (3.1.8)
# Requirement already satisfied: colorama in c:\users\sirap\appdata\roaming\python\python312\site-packages (from click>=8.1.3->flask) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from flask import Flask, request, jsonify


app = Flask(__name__)

@app.route('/predict', methods=['POST'])
def predict():

    # รับ input (จำนวนปีและจำนวนเงินเริ่มต้น) จาก request
    data = request.get_json()

    try:
        # แปลงค่า n_years และ initial_amount เป็น int
        n_years = int(data.get('n_years'))
        initial_amount = float(data.get('initial_amount'))
    except ValueError:
        return jsonify({'error': 'Invalid input. Ensure that n_years and initial_amount are integers.'}), 400

    # เรียกใช้ฟังก์ชันใน models.py เพื่อทำนายผล
    predictions = predict(n_years, initial_amount)

    # ส่งคืนผลลัพธ์กลับเป็น JSON
    return jsonify(predictions)

if __name__ == '__main__':
    port = int(os.environ.get('PORT', 5050))
    app.run(debug=False,host='0.0.0.0' ,port=port)
    print(f"🚀 Model Api running at http://localhost:{port}")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5050
#  * Running on http://192.168.1.41:5050
# Press CTRL+C to quit
# 127.0.0.1 - - [03/Aug/2026 18:04:59] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [03/Aug/2026 18:04:59] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [03/Aug/2026 18:05:12] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2026 18:05:18] "OPTIONS /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [03/Aug/2026 18:06:15] "OPTIONS /predict HTTP/1.1" 200 -
# 🚀 Model Api running at http://localhost:5050
